# %%
# モバオクから金券データを取得する


# coding: utf-8
import requests
from bs4 import BeautifulSoup
import re
import os
import sys
from time import sleep

# 第一引数にURLを、第二引数にフォルダ名となる
# アーティスト名を入れる

#2019-03-12みたいな日付けを作る
def formatted_today():
    import datetime
    now = datetime.datetime.now()
    today = "{0:%Y-%m-%d}".format(now)
    return today

def print_line():
    print("---------------------------------------------------------------------------------------------------------------------------------------")

def sleep_(sec):
    print("過剰な連続リクエスト回避のsleep:"+str(sec)+"秒")
    sleep(sec)



# src_urlからソースを取ってくる。query_nameを指定するとフォルダを作成できる。
#  query_name= ジャニーズJr→ ジャニーズJr/2019-05-17 みたいにフォルダを生成できる
def get_save(query_name, url):
    
    print("クローリングを開始します")
    print("項目名: "+query_name)

    
#     試しに一回取得
    r = requests.get(url)
    soup  = BeautifulSoup(r.text,"html.parser").body
    sleep_(2)

# 全件を保存する為にページ数を計上
# ページ数は .pager-countクラスの最後のノードに格納されている
    pager_counts  = soup.select(".pnlink")
    print(pager_counts)
    length = len(pager_counts)
#     最後の.pager-countの番号：ページネーション数を計上 →63
    last_page = pager_counts[length-1].find("span").text
    print("総ページ数: "+last_page)

#     1→63までループ
    for i in range(1, int(last_page)+1):

        print(query_name+"の"+str(i)+" ページ目のクローリングを開始...")

        url += ("&pn=" +last_page)
        r = requests.get(url)
        soup = BeautifulSoup(r.text, "html.parser")
        print(str(i)+"ページ目取得完了...")
# 日付けからディレクトリ作成
        date = formatted_today()
        combined_path = query_name+"/"+date
        os.makedirs(combined_path, exist_ok=True)
#     書き込み
        with open (combined_path+"/"+"ticket-data"+str(i)+".html", mode="w", encoding="utf-8") as fw:
            fw.write(soup.prettify())
            print(query_name+"の"+str(i)+"ページ目の保存中...")

        print(query_name+"の"+str(i)+" ページ目の保存を完了しました。")
        sleep_(2)


# get_save(url, name)

name ="金券"
url = "view-source:https://www.mbok.jp/category/categ_600000001.html"
# for name, url in artists.items():
get_save(name,url)
sleep_(2)


print_line()
print("全金券データのクローリングを完了しました")
print_line()

# 備考
# CSSはダウンロードできない。一応ソースから手作業で探してくることはできた。

# URLとアーティスト名はコマンドライン引数で渡せるべき
# Out:
# クローリングを開始します
# 項目名: 金券
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# <ipython-input-1-f562bab12444> in <module>
#      78 url = "view-source:https://www.mbok.jp/category/categ_600000001.html"
#      79 # for name, url in artists.items():
# ---> 80 get_save(name,url)
#      81 sleep_(2)
#      82
#
# <ipython-input-1-f562bab12444> in get_save(query_name, url)
#      38
#      39 #     試しに一回取得
# ---> 40     r = requests.get(url)
#      41     soup  = BeautifulSoup(r.text,"html.parser").body
#      42     sleep_(2)
#
# ~/ticket_tenbai/my_env/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/ticket_tenbai/my_env/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/ticket_tenbai/my_env/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/ticket_tenbai/my_env/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     638
#     639         # Get the appropriate adapter to use
# --> 640         adapter = self.get_adapter(url=request.url)
#     641
#     642         # Start time (approximately) of the request
#
# ~/ticket_tenbai/my_env/lib/python3.7/site-packages/requests/sessions.py in get_adapter(self, url)
#     729
#     730         # Nothing matches :-/
# --> 731         raise InvalidSchema("No connection adapters were found for '%s'" % url)
#     732
#     733     def close(self):
#
# InvalidSchema: No connection adapters were found for 'view-source:https://www.mbok.jp/category/categ_600000001.html'
