# %%
# アイドルグループは平均年齢を設けたので演歌グループもアーティストごとの年齢を出すことにする
# 目標は定価をあぶりだすこと
# その過程で


import pandas as pd

# %%
df = pd.read_csv("../CSV/演歌/演歌.csv")
print(df["name"].unique()) 
print(df["name"].unique().shape) #289
# Out:
# ['氷川きよし特別公演新歌舞伎座5/23 夜S席1階8~10列センターブロック1 ~2枚'
#  '★2019年7月13日(土曜日)に大阪である大阪新歌舞伎座開場60周年記念市川由紀乃コンサートのチケット送料込み!'
#  'ごごウタ NHK みんなの広場 ふれあいホール 5/24 (金) 1枚2枚様 入場整理券 小堺一機,塚原愛,おかゆ,門倉有希,北島兄弟,神野美伽,ほか'
#  '松平健川中美幸特別公演6月8日土曜日11時開演新歌舞伎座1階18列2枚ペア' '氷川きよし 特別公演 新歌舞伎座'
#  '氷川きよし特別公演♪新歌舞伎座5/26(日)昼1階1列送料込み1枚' '氷川きよし 特別公演'
#  '入場券「八代亜紀コンサート2019」ゲスト北川大介2019年6月14日夜の部津田沼文化ホール'
#  '森昌子祝還暦コンサート7月22日14時江戸川区総合文化センター。プレミアシート。7列20'
#  '氷川きよし 特別公演 5/25 2階S席 2枚連番' '◇格安S席9000円◇氷川きよし1階16列◇5/25(夜)新歌舞伎座 1枚'
#  '氷川きよし 特別公演 新歌舞伎座 5月26日夜の部1階11列 ペアチケット' '氷川きよし特別公演新歌舞伎座5月24日昼1階5列目良席1枚'
#  '氷川きよし 新歌舞伎座 特別公演 5月23日(夜) S席 2枚連番 速達'
#  '氷川きよし新歌舞伎座特別公演5/22夜S席ペア定価以下即決ありおまけ付' '福田こうへいコンサートチケット松戸森のホール21SS席5月28日'
#  '氷川きよし特別公演新歌舞伎座5月26日(日)昼の部S席6列' '氷川きよし 新歌舞伎座 5月26日 夜の部S席1枚'
#  '【京都】福田こうへいコンサート/石川さゆりコンサート★割引予約券'
#  '★★ 2019.8.1 夜の部プレミアムチケット 連続2席分森昌子厚木市民文化会館 ★★'
#  '氷川きよし特別公演 新歌舞伎座 5/25(昼)S席1枚' '大月みやこ歌謡ショー チケット2枚 大月みやこ歌謡ショー チケット2枚'
#  '♪氷川きよし特別公演新歌舞伎座♪5/23 昼 1階S席 ペア 定価以下' '☆ 島津亜矢コンサート 5月25日(土) 1階10列 ☆'
# ...

# %%
names = pd.DataFrame(df["name"].unique(),columns=["name"])
names.to_excel("../その他データ/演歌歌手年齢定価データ.xls")
